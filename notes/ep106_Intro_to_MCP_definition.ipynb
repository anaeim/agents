# %% [markdown]
# ## what is not and what is MCP?

# %% [markdown]
# #### what is MCP?
# It’s a protocol—a standard—that provides a consistent and easy way of doing things. In practice, it offers a simple method for integrating your agents with tools, resources, or prompts.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
