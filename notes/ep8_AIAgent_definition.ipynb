# %% [markdown]
# ## what is Ai agent?
# huggingface definition:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# general definition in practice:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### antropic definition for AIAgent
# based on [Building effective agents](https://www.anthropic.com/engineering/building-effective-agents) blog post by Antropic, they distinguish two types of what they call agentic system. So that's this is their terminology. But they would say that there are, there's this umbrella term agentic system. And under that umbrella term there are two different categories.
#
# you can see they're sort of hinting that perhaps the things that a lot of people call agents are in fact workflows. So they're drawing that distinction, but they do still describe the whole thing as being a genetic systems. So it's a bit of wordplay there.
#
# ![image.png](attachment:image.png)
